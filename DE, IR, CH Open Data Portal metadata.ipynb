# %%
import requests
import json
import time

# Define the base URL for the CKAN API
base_url = "https://www.govdata.de/ckan/api/3/action/"

# Function to get a specified number of datasets with pagination
def get_recent_datasets_metadata(limit=15000, chunk_size=100, timeout=2):
    datasets = []
    rows = 100  # Number of datasets per request (max 1000 according to CKAN API)
    start = 0
    
    while start < limit:
        search_url = base_url + "package_search"
        params = {
            "rows": min(rows, limit - start),
            "start": start
        }
        response = requests.get(search_url, params=params)
        data = response.json()
        
        if not data['success']:
            break
        
        results = data['result']['results']
        if not results:
            break
        
        datasets.extend(results)
        start += rows
        
        # Print progress in chunks to avoid overwhelming the output buffer
        if len(datasets) % chunk_size == 0:
            print(f"Retrieved {len(datasets)} datasets so far...")
        
        # Introduce a delay to avoid hitting the server too hard
        time.sleep(timeout)
    
    return datasets

# Example usage
if __name__ == "__main__":
    recent_datasets_metadata = get_recent_datasets_metadata(limit=15000)
    
    # Save the results to a file to avoid overwhelming Jupyter output
    with open('datasets_metadata.json', 'w') as f:
        json.dump(recent_datasets_metadata, f, indent=4)
    
    print(f"Retrieved metadata for {len(recent_datasets_metadata)} datasets. Data saved to 'datasets_metadata_germany.json'.")
# Out:
# Retrieved 100 datasets so far...
# Retrieved 200 datasets so far...
# Retrieved 300 datasets so far...
# Retrieved 400 datasets so far...
# Retrieved 500 datasets so far...
# Retrieved 600 datasets so far...
# Retrieved 700 datasets so far...
# Retrieved 800 datasets so far...
# Retrieved 900 datasets so far...
# Retrieved 1000 datasets so far...
# Retrieved 1100 datasets so far...
# Retrieved 1200 datasets so far...
# Retrieved 1300 datasets so far...
# Retrieved 1400 datasets so far...
# Retrieved 1500 datasets so far...
# Retrieved 1600 datasets so far...
# Retrieved 1700 datasets so far...
# Retrieved 1800 datasets so far...
# Retrieved 1900 datasets so far...
# Retrieved 2000 datasets so far...
# Retrieved 2100 datasets so far...
# Retrieved 2200 datasets so far...
# Retrieved 2300 datasets so far...
# Retrieved 2400 datasets so far...
# Retrieved 2500 datasets so far...
# Retrieved 2600 datasets so far...
# Retrieved 2700 datasets so far...
# Retrieved 2800 datasets so far...
# Retrieved 2900 datasets so far...
# Retrieved 3000 datasets so far...
# Retrieved 3100 datasets so far...
# Retrieved 3200 datasets so far...
# Retrieved 3300 datasets so far...
# Retrieved 3400 datasets so far...
# Retrieved 3500 datasets so far...
# Retrieved 3600 datasets so far...
# Retrieved 3700 datasets so far...
# Retrieved 3800 datasets so far...
# Retrieved 3900 datasets so far...
# Retrieved 4000 datasets so far...
# Retrieved 4100 datasets so far...
# Retrieved 4200 datasets so far...
# Retrieved 4300 datasets so far...
# Retrieved 4400 datasets so far...
# Retrieved 4500 datasets so far...
# Retrieved 4600 datasets so far...
# Retrieved 4700 datasets so far...
# Retrieved 4800 datasets so far...
# Retrieved 4900 datasets so far...
# Retrieved 5000 datasets so far...
# Retrieved 5100 datasets so far...
# Retrieved 5200 datasets so far...
# Retrieved 5300 datasets so far...
# Retrieved 5400 datasets so far...
# Retrieved 5500 datasets so far...
# Retrieved 5600 datasets so far...
# Retrieved 5700 datasets so far...
# Retrieved 5800 datasets so far...
# Retrieved 5900 datasets so far...
# Retrieved 6000 datasets so far...
# Retrieved 6100 datasets so far...
# Retrieved 6200 datasets so far...
# Retrieved 6300 datasets so far...
# Retrieved 6400 datasets so far...
# Retrieved 6500 datasets so far...
# Retrieved 6600 datasets so far...
# Retrieved 6700 datasets so far...
# Retrieved 6800 datasets so far...
# Retrieved 6900 datasets so far...
# Retrieved 7000 datasets so far...
# Retrieved 7100 datasets so far...
# Retrieved 7200 datasets so far...
# Retrieved 7300 datasets so far...
# Retrieved 7400 datasets so far...
# Retrieved 7500 datasets so far...
# Retrieved 7600 datasets so far...
# Retrieved 7700 datasets so far...
# Retrieved 7800 datasets so far...
# Retrieved 7900 datasets so far...
# Retrieved 8000 datasets so far...
# Retrieved 8100 datasets so far...
# Retrieved 8200 datasets so far...
# Retrieved 8300 datasets so far...
# Retrieved 8400 datasets so far...
# Retrieved 8500 datasets so far...
# Retrieved 8600 datasets so far...
# Retrieved 8700 datasets so far...
# Retrieved 8800 datasets so far...
# Retrieved 8900 datasets so far...
# Retrieved 9000 datasets so far...
# Retrieved 9100 datasets so far...
# Retrieved 9200 datasets so far...
# Retrieved 9300 datasets so far...
# Retrieved 9400 datasets so far...
# Retrieved 9500 datasets so far...
# Retrieved 9600 datasets so far...
# Retrieved 9700 datasets so far...
# Retrieved 9800 datasets so far...
# Retrieved 9900 datasets so far...
# Retrieved 10000 datasets so far...
# Retrieved 10100 datasets so far...
# Retrieved 10200 datasets so far...
# Retrieved 10300 datasets so far...
# Retrieved 10400 datasets so far...
# Retrieved 10500 datasets so far...
# Retrieved 10600 datasets so far...
# Retrieved 10700 datasets so far...
# Retrieved 10800 datasets so far...
# Retrieved 10900 datasets so far...
# Retrieved 11000 datasets so far...
# Retrieved 11100 datasets so far...
# Retrieved 11200 datasets so far...
# Retrieved 11300 datasets so far...
# Retrieved 11400 datasets so far...
# Retrieved 11500 datasets so far...
# Retrieved 11600 datasets so far...
# Retrieved 11700 datasets so far...
# Retrieved 11800 datasets so far...
# Retrieved 11900 datasets so far...
# Retrieved 12000 datasets so far...
# Retrieved 12100 datasets so far...
# Retrieved 12200 datasets so far...
# Retrieved 12300 datasets so far...
# Retrieved 12400 datasets so far...
# Retrieved 12500 datasets so far...
# Retrieved 12600 datasets so far...
# Retrieved 12700 datasets so far...
# Retrieved 12800 datasets so far...
# Retrieved 12900 datasets so far...
# Retrieved 13000 datasets so far...
# Retrieved 13100 datasets so far...
# Retrieved 13200 datasets so far...
# Retrieved 13300 datasets so far...
# Retrieved 13400 datasets so far...
# Retrieved 13500 datasets so far...
# Retrieved 13600 datasets so far...
# Retrieved 13700 datasets so far...
# Retrieved 13800 datasets so far...
# Retrieved 13900 datasets so far...
# Retrieved 14000 datasets so far...
# Retrieved 14100 datasets so far...
# Retrieved 14200 datasets so far...
# Retrieved 14300 datasets so far...
# Retrieved 14400 datasets so far...
# Retrieved 14500 datasets so far...
# Retrieved 14600 datasets so far...
# Retrieved 14700 datasets so far...
# Retrieved 14800 datasets so far...
# Retrieved 14900 datasets so far...
# Retrieved 15000 datasets so far...
# Retrieved metadata for 15000 datasets. Data saved to 'datasets_metadata.json'.

# %%
import pandas as pd

df = pd.DataFrame(recent_datasets_metadata)

# %%
df
# Out:
#                                                   author  \
# 0        Hanse- und Universitätsstadt Rostock – Hauptamt
# 1      Hanse- und Universitätsstadt Rostock – Kataste...
# 2      Hanse- und Universitätsstadt Rostock – Kataste...
# 3      Hanse- und Universitätsstadt Rostock – Kataste...
# 4        Hanse- und Universitätsstadt Rostock – Hauptamt
# ...                                                  ...
# 14995                              Verbandsgemeinde Eich
# 14996                          Ortsgemeinde Schwedelbach
# 14997                      Verbandsgemeinde Altenkirchen
# 14998                           Ortsgemeinde Erzenhausen
# 14999                      Verbandsgemeinde Altenkirchen
#
#                      author_email                       creator_user_id  \
# 0           geodienste@rostock.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
# 1           geodienste@rostock.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
# 2           geodienste@rostock.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
# 3           geodienste@rostock.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
# 4           geodienste@rostock.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
# ...                           ...                                   ...
# 14995       poststelle@vg-eich.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
# 14996       info@vg-weilerbach.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
# 14997  rathaus@vg-altenkirchen.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
# 14998       info@vg-weilerbach.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
# 14999  rathaus@vg-altenkirchen.de  f512f73d-bed2-439d-8f6f-3fbc6048b24e
#
#                                          id  isopen license_id license_title  \
# 0      05be0aa5-76a2-4850-b37f-69e623565fbe   False
# 1      44fa7d61-7924-4740-95ec-b4a6821139fe   False
# 2      6219e4c3-e819-40f0-86cd-543ff829ad6c   False
# 3      7c46a2cc-4fe3-4399-8833-61b016730b71   False
# 4      4d25536c-7cc4-4761-8504-0ba8ca320fa1   False
# ...                                     ...     ...        ...           ...
# 14995  e725ccc0-5267-4bd0-b81c-32515ab32d8f   False
# 14996  1620d684-d596-46b7-bc24-40250d38a402   False
# 14997  386ee29a-4ee2-4291-8f78-07d163230060   False
# 14998  d4ebb690-762e-4624-864d-d03383a36ada   False
# 14999  1f5edc12-687f-4575-b200-de66968759ae   False
#
#                                               maintainer  \
# 0      Hanse- und Universitätsstadt Rostock – Kataste...
# 1      Hanse- und Universitätsstadt Rostock – Kataste...
# 2      Hanse- und Universitätsstadt Rostock – Kataste...
# 3      Hanse- und Universitätsstadt Rostock – Kataste...
# 4      Hanse- und Universitätsstadt Rostock – Kataste...
# ...                                                  ...
# 14995                                               None
# 14996                                               None
# 14997                                               None
# 14998                                               None
# 14999                                               None
#
#             maintainer_email            metadata_created  ...  \
# 0      geodienste@rostock.de  2023-01-06T06:14:11.920576  ...
# 1      geodienste@rostock.de  2024-05-08T06:31:53.940777  ...
# 2      geodienste@rostock.de  2024-05-08T06:31:46.141017  ...
# 3      geodienste@rostock.de  2024-05-08T06:32:00.483952  ...
# 4      geodienste@rostock.de  2024-05-08T06:32:18.276436  ...
# ...                      ...                         ...  ...
# 14995                   None  2022-01-26T10:17:23.776277  ...
# 14996                   None  2023-08-07T04:51:22.657594  ...
# 14997                   None  2022-01-26T09:30:21.252167  ...
# 14998                   None  2023-08-07T04:51:33.293593  ...
# 14999                   None  2022-01-26T09:34:13.821166  ...
#
#                                       title     type  \
# 0                       Bundestagswahl 2013  dataset
# 1                      Bodenrichtwerte 2015  dataset
# 2                      Bodenrichtwerte 2008  dataset
# 3      38. Internationaler Hansetag Rostock  dataset
# 4                          Ortsamtsbereiche  dataset
# ...                                     ...      ...
# 14995                         Die Mühläcker  dataset
# 14996                      Auf dem Hebel II  dataset
# 14997   Wochenendhausgebiet Kircheiber Born  dataset
# 14998                Im Borfeld Änderung II  dataset
# 14999                    Auf dem Pferdsborn  dataset
#
#                                                      url  version  \
# 0      https://www.opendata-hro.de/dataset/e7c10dd4-d...     None
# 1      https://www.opendata-hro.de/dataset/c276228b-9...     None
# 2      https://www.opendata-hro.de/dataset/655f46c2-1...     None
# 3      https://www.opendata-hro.de/dataset/7afdfa7a-7...     None
# 4      https://www.opendata-hro.de/dataset/aceccfc0-d...     None
# ...                                                  ...      ...
# 14995                                               None     None
# 14996                                               None     None
# 14997                                               None     None
# 14998                                               None     None
# 14999                                               None     None
#
#                                                   extras  \
# 0      [{'key': 'access_rights', 'value': 'http://pub...
# 1      [{'key': 'access_rights', 'value': 'http://pub...
# 2      [{'key': 'access_rights', 'value': 'http://pub...
# 3      [{'key': 'access_rights', 'value': 'http://pub...
# 4      [{'key': 'access_rights', 'value': 'http://pub...
# ...                                                  ...
# 14995  [{'key': 'author_contacttype', 'value': 'Organ...
# 14996  [{'key': 'author_contacttype', 'value': 'Organ...
# 14997  [{'key': 'author_contacttype', 'value': 'Organ...
# 14998  [{'key': 'author_contacttype', 'value': 'Organ...
# 14999  [{'key': 'author_contacttype', 'value': 'Organ...
#
#                                                   groups  \
# 0      [{'description': '', 'display_name': 'Regierun...
# 1      [{'description': '', 'display_name': 'Regierun...
# 2      [{'description': '', 'display_name': 'Regierun...
# 3      [{'description': '', 'display_name': 'Bildung,...
# 4      [{'description': '', 'display_name': 'Regierun...
# ...                                                  ...
# 14995  [{'description': '', 'display_name': 'Bevölker...
# 14996  [{'description': '', 'display_name': 'Bevölker...
# 14997  [{'description': '', 'display_name': 'Bevölker...
# 14998  [{'description': '', 'display_name': 'Bevölker...
# 14999  [{'description': '', 'display_name': 'Bevölker...
#
#                                                resources  \
# 0      [{'access_url': 'https://geo.sv.rostock.de/dow...
# 1      [{'access_url': 'https://geo.sv.rostock.de/dow...
# 2      [{'access_url': 'https://geo.sv.rostock.de/dow...
# 3      [{'access_url': 'https://geo.sv.rostock.de/dow...
# 4      [{'access_url': 'https://geo.sv.rostock.de/dow...
# ...                                                  ...
# 14995  [{'access_url': 'https://www.geoportal.rlp.de/...
# 14996  [{'access_url': 'https://www.geoportal.rlp.de/...
# 14997  [{'access_url': 'https://www.geoportal.rlp.de/...
# 14998  [{'access_url': 'https://www.geoportal.rlp.de/...
# 14999  [{'access_url': 'https://www.geoportal.rlp.de/...
#
#                                                     tags  \
# 0      [{'display_name': 'politik', 'id': 'a8e6e4aa-6...
# 1      [{'display_name': 'bauleitplanung', 'id': '861...
# 2      [{'display_name': 'bauleitplanung', 'id': '861...
# 3      [{'display_name': 'freizeit', 'id': '73a5f345-...
# 4      [{'display_name': 'behörde', 'id': 'e15183d8-d...
# ...                                                  ...
# 14995  [{'display_name': 'bauleitplan', 'id': '8dfff9...
# 14996  [{'display_name': 'bauleitplan', 'id': '8dfff9...
# 14997  [{'display_name': 'bauleitplan', 'id': '8dfff9...
# 14998  [{'display_name': 'bauleitplan', 'id': '8dfff9...
# 14999  [{'display_name': 'bauleitplan', 'id': '8dfff9...
#
#       relationships_as_subject relationships_as_object
# 0                           []                      []
# 1                           []                      []
# 2                           []                      []
# 3                           []                      []
# 4                           []                      []
# ...                        ...                     ...
# 14995                       []                      []
# 14996                       []                      []
# 14997                       []                      []
# 14998                       []                      []
# 14999                       []                      []
#
# [15000 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['author', 'author_email', 'creator_user_id', 'id', 'isopen',
#        'license_id', 'license_title', 'maintainer', 'maintainer_email',
#        'metadata_created', 'metadata_modified', 'name', 'notes',
#        'num_resources', 'num_tags', 'organization', 'owner_org', 'private',
#        'state', 'title', 'type', 'url', 'version', 'extras', 'groups',
#        'resources', 'tags', 'relationships_as_subject',
#        'relationships_as_object'],
#       dtype='object')

# %%
df.url.tolist()
# Out:
# ['https://www.opendata-hro.de/dataset/e7c10dd4-d8fb-440c-9fc1-e2649b73e5d7',
#  'https://www.opendata-hro.de/dataset/c276228b-9c7b-4812-b4a5-7480316c2233',
#  'https://www.opendata-hro.de/dataset/655f46c2-102b-45a6-a9c4-cc7cb56d47df',
#  'https://www.opendata-hro.de/dataset/7afdfa7a-7fd4-48a2-be63-e83750eb1c40',
#  'https://www.opendata-hro.de/dataset/aceccfc0-dbf2-42a3-9456-389c6a0edb7c',
#  'https://www.opendata-hro.de/dataset/8c74c345-92a1-4245-a42a-71c0beef8160',
#  'https://www.opendata-hro.de/dataset/b5375466-e593-4a0e-9005-ab6a9bc22395',
#  'https://www.opendata-hro.de/dataset/f709d112-a2d1-4098-a8ca-41e364899490',
#  'https://www.opendata-hro.de/dataset/7c3a523b-6ef0-46f7-851b-da5340852439',
#  'https://www.opendata-hro.de/dataset/d59dfb19-d22d-421d-b4af-53a600a18cbd',
#  'https://www.opendata-hro.de/dataset/a3ccc8c3-810d-49c2-a1c2-b82645e87c97',
#  'https://www.opendata-hro.de/dataset/bdbbae58-41e0-4453-bfe3-369e5c427cd0',
#  'https://www.opendata-hro.de/dataset/d02483e4-6dca-45ee-9cf4-97cf27742179',
#  'https://www.opendata-hro.de/dataset/c7629958-542f-49d4-ad38-ec3b85700107',
#  'https://www.opendata-hro.de/dataset/ec7d53de-cf58-4c3d-b9f1-a468cdfccb02',
#  'https://www.opendata-hro.de/dataset/6eaf8733-5bbb-43ec-8d24-b9a439bae1ba',
#  'https://www.opendata-hro.de/dataset/a4bc37fd-6e7c-450a-b783-5bc201174d3a',
#  'https://www.opendata-hro.de/dataset/6a218346-593a-478c-ae3e-937e254947e3',
#  'https://www.opendata-hro.de/dataset/d31b7c96-c44a-46d3-87b7-e6275d7637ca',
#  'https://www.opendata-hro.de/dataset/fe933fc6-3c0d-44a5-bd14-75d79a50b0c0',
#  'https://www.opendata-hro.de/dataset/d418059b-0e60-4995-91e9-7a9a17f4b3aa',
#  'https://www.opendata-hro.de/dataset/fab4bc16-6705-4d2e-ae8b-9d1382a3cbfe',
#  'https://www.opendata-hro.de/dataset/558c20e8-6e2b-4acb-9640-a8773f091acb',
#  'https://www.opendata-hro.de/dataset/45e94633-189b-4857-b710-f9b6fb4aa7a8',
#  'https://www.opendata-hro.de/dataset/b9173e26-0b66-4fa1-84e8-e2662e1c5f79',
#  'https://www.opendata-hro.de/dataset/abbf8ddc-7d87-4c89-9cb4-42a44ab4f9a6',
#  'https://www.opendata-hro.de/dataset/008b0185-a5b3-4b70-af94-617f692760fa',
#  'https://www.opendata-hro.de/dataset/0fc59922-12fa-4749-bf61-a3b391e3c12a',
#  'https://www.opendata-hro.de/dataset/eacf9124-26c0-4e3e-919e-9800eb2264a5',
#  'https://www.opendata-hro.de/dataset/c3c935a0-a8fb-45ec-a4cc-aba211c2d978',
#  'https://www.opendata-hro.de/dataset/7ac909c7-7d73-4ec8-8610-7fe6594ddc93',
#  'https://www.opendata-hro.de/dataset/e9fda07a-424b-4e63-8aa1-2c24313b9002',
#  'https://www.opendata-hro.de/dataset/312bb56d-15b4-4aa0-a1bd-2e867dd95e4a',
#  'https://www.opendata-hro.de/dataset/f508e9f3-17db-4bb1-916b-bdbb9295bde0',
#  'https://www.opendata-hro.de/dataset/57d5321a-0e83-4961-894f-e1f757be41ca',
#  'https://www.opendata-hro.de/dataset/c965a646-70fd-46e9-8ffb-b3254f9a3a4b',
#  'https://www.opendata-hro.de/dataset/42811a30-deb9-4650-a8aa-d9a93d97e2dc',
#  'https://www.opendata-hro.de/dataset/0b315fcd-f0ff-49ca-8d28-590db57e161f',
#  'https://www.opendata-hro.de/dataset/e0f296a7-adbe-4a0f-a0f6-6a464b3e6dc7',
#  'https://www.opendata-hro.de/dataset/95235ea3-87a2-4a9a-aedc-f171107ead85',
#  'https://www.opendata-hro.de/dataset/4aa382d5-4fe7-446f-88cb-1f5c5c6bf67a',
#  'https://www.opendata-hro.de/dataset/28614843-8f98-4ef5-8ac4-4956ae2455ba',
#  'https://www.opendata-hro.de/dataset/38cc66ec-be3c-45e3-bef3-c781ed9c1e2d',
#  'https://www.opendata-hro.de/dataset/dd8a8a8a-797d-494b-8586-09d1f57fb0a2',
#  'https://www.opendata-hro.de/dataset/92437de0-a730-428a-921d-1d9c418072d6',
#  'https://www.opendata-hro.de/dataset/e2ae83b6-9b9b-4f07-8399-35442395299c',
#  'https://www.opendata-hro.de/dataset/7048ddc7-c9c1-4017-bef6-b679e243631b',
#  'https://www.opendata-hro.de/dataset/35f1b6c2-f173-4205-8dd3-7ad53db0f64f',
#  'https://www.opendata-hro.de/dataset/821ea501-d5a9-46b8-aa21-e01f4f9dbd22',
#  'https://www.opendata-hro.de/dataset/3c62113e-9635-41b2-acda-2f174a4ee7c7',
#  'https://www.opendata-hro.de/dataset/ca6846a1-5bf5-46a9-9b2f-5f7cb25fef6b',
#  'https://www.opendata-hro.de/dataset/69a0c2e9-85fc-4a3e-81cf-393d1970062e',
#  'https://www.opendata-hro.de/dataset/72f7e58c-33a2-4b86-bbf4-779fba1eb31a',
#  'https://www.opendata-hro.de/dataset/15c1277f-5b7b-445e-a7c0-a80c714c042a',
#  'https://www.opendata-hro.de/dataset/86cf99e9-103c-4598-988f-d7e536a7e155',
#  'https://www.opendata-hro.de/dataset/ef69aa52-2315-4ec4-a62c-a625834e5fa9',
#  'https://www.opendata-hro.de/dataset/299dbf43-3fb5-471f-a0fa-2c8b7ce9e19c',
#  'https://www.opendata-hro.de/dataset/5563ebe9-12bf-4aa1-8d85-1d67bfd1a342',
#  'https://www.opendata-hro.de/dataset/0b6df6d9-0720-4d75-9db9-c63f16536aa2',
#  'https://www.opendata-hro.de/dataset/c2f73bc6-02dd-48ae-b9c6-4b8fe14da580',
#  'https://www.opendata-hro.de/dataset/b879e3cf-7671-4989-aa3a-5c8cbc7442bd',
#  'https://www.opendata-hro.de/dataset/d1b9d1eb-4d62-4996-ae7e-281195d3b766',
#  'https://www.opendata-hro.de/dataset/0c09f284-6b90-402b-83c8-5eefdb381bbe',
#  'https://www.opendata-hro.de/dataset/c5621575-1017-48f9-b34a-bb9fe4a71f3e',
#  'https://www.opendata-hro.de/dataset/9428cf36-a3a9-40bc-9d82-3964ae497c9b',
#  'https://www.opendata-hro.de/dataset/de4cc79a-137f-4467-b5c3-302d2d465f07',
#  'https://www.opendata-hro.de/dataset/1d163996-5ed7-488d-8d8e-11910a3c99c2',
#  'https://www.opendata-hro.de/dataset/d6fcf920-6934-486a-8037-2a88964c7cdd',
#  'https://www.opendata-hro.de/dataset/def01e2f-270d-450d-a329-557e635c37d5',
#  'https://www.opendata-hro.de/dataset/0bd49d5f-cd42-44a9-8938-75173fe07b17',
#  'https://www.opendata-hro.de/dataset/1b59b3e2-a01a-4b42-9a67-f133f66438c6',
#  'https://www.opendata-hro.de/dataset/cb0ebb4f-7049-4a77-ac9d-812c6754d734',
#  'https://www.opendata-hro.de/dataset/7cc90153-1106-4f80-9270-6f99cafa4ba1',
#  'https://www.opendata-hro.de/dataset/e6b84bd2-339a-43c2-94b8-b92a3f0dc4b9',
#  'https://www.opendata-hro.de/dataset/c2e39d12-5675-4f08-b92d-9a84ed449ef7',
#  'https://www.opendata-hro.de/dataset/01d00406-1f5a-428e-b4c8-cee1687d67c6',
#  'https://www.opendata-hro.de/dataset/6bfac7ac-6ac6-4415-b90a-19343c3e9386',
#  'https://www.opendata-hro.de/dataset/debb7ae4-6149-47ac-bc34-3a4cc38e8a8a',
#  'https://www.opendata-hro.de/dataset/220781e3-2e11-4e06-955c-6bf5307973ff',
#  'https://www.opendata-hro.de/dataset/6ee78950-927b-41da-bf11-cc834137f4f1',
#  'https://www.opendata-hro.de/dataset/a9f354fb-a94f-4b65-a4d2-de12ac7279b7',
#  'https://www.opendata-hro.de/dataset/8604e283-9439-4009-9139-67031fcfb2d8',
#  'https://www.opendata-hro.de/dataset/b56d16f0-2be4-40c0-8145-ec0694a142ca',
#  'https://www.opendata-hro.de/dataset/521be01f-6939-4f5e-8a0c-cb77ed3206e0',
#  'https://www.opendata-hro.de/dataset/82885048-c573-4685-9a49-bc75bf5048fc',
#  'https://www.opendata-hro.de/dataset/c3d9bc4f-4828-4d19-ae36-f7d8c44702be',
#  'https://www.opendata-hro.de/dataset/7b7cf544-204c-420b-bde9-3a0a3be9c789',
#  'https://www.opendata-hro.de/dataset/b6804103-8124-459d-9e6a-542c425d7e29',
#  'https://www.opendata-hro.de/dataset/ddde5c21-f067-4405-99ff-c5d6ddc9b8fc',
#  'https://www.opendata-hro.de/dataset/89413ed1-ad41-4211-a144-212172e50545',
#  'https://www.opendata-hro.de/dataset/5f7ddbd5-84e0-4eaf-8e24-4484e46527fb',
#  'https://www.opendata-hro.de/dataset/d7f5a5e3-64c8-4f13-9613-a01b440f2610',
#  'https://www.opendata-hro.de/dataset/e424e6df-57b0-49a6-ae63-04acb4539367',
#  'https://www.opendata-hro.de/dataset/c3cadd4c-b27d-40d7-b98b-e618cf84b89e',
#  'https://www.opendata-hro.de/dataset/f596c93b-5543-483e-9642-77588495b6c1',
#  'https://www.opendata-hro.de/dataset/4e932629-4bc2-4b23-9642-8076ee9fb8d4',
#  'https://www.opendata-hro.de/dataset/613c98c1-2cc2-4bd1-b298-f3a9716c3755',
#  'https://www.opendata-hro.de/dataset/69135f93-3858-4afd-b760-bb36b51e6e9d',
#  'https://www.opendata-hro.de/dataset/b6cadf55-e2e2-4113-9821-e2f2adcae5c1',
#  'https://www.opendata-hro.de/dataset/65a8d161-e14c-4215-8805-b3e6a2edf2e2',
#  'https://www.opendata-hro.de/dataset/9d8d6332-2d39-408a-9cfb-c509961e2c3c',
#  'https://www.opendata-hro.de/dataset/61067a6d-0e7c-4ac4-8864-51afaa895994',
#  'https://www.opendata-hro.de/dataset/c952cb9c-eb1e-4a19-8817-e52f6639b57e',
#  'https://www.opendata-hro.de/dataset/e543112e-7f46-42bf-ab8c-23fa7774a034',
#  'https://www.opendata-hro.de/dataset/32fd65c7-4bd2-46a3-b78b-2c2b480736fa',
#  'https://www.opendata-hro.de/dataset/ecb362e0-49d5-4bf2-a3a2-17851c6ac9f4',
#  'https://www.opendata-hro.de/dataset/40451db0-3b65-4e98-83f4-de0c1116d11d',
#  'https://www.opendata-hro.de/dataset/1f375e7a-61ef-4af8-9745-d0f7bb3149a1',
#  'https://www.opendata-hro.de/dataset/943bd383-b052-4c7f-8174-dfbdbb4de3a7',
#  'https://www.opendata-hro.de/dataset/209226f8-5155-4241-9cd1-2fd32253a803',
#  'https://www.opendata-hro.de/dataset/36fd8473-380c-40ce-95df-ac872cc13405',
#  'https://www.opendata-hro.de/dataset/aa692117-79fb-4d7a-87f9-d84db751aa3f',
#  'https://www.opendata-hro.de/dataset/ae5e53ed-3fda-495f-81ce-fe65163bf4c2',
#  'https://www.opendata-hro.de/dataset/31e6734c-84dd-4671-9b19-680910ebc0db',
#  'https://www.opendata-hro.de/dataset/b13647f2-617e-40ac-8551-0ae77c9584bf',
#  'https://www.opendata-hro.de/dataset/652e7b9e-5bb2-4a7e-aeff-12421d3c32a5',
#  'https://www.opendata-hro.de/dataset/aca0b5e5-d897-4ce3-8117-059cbd73d7e0',
#  'https://www.opendata-hro.de/dataset/3f9c3016-fc26-40af-96d4-f9cd5037ca6d',
#  'https://www.opendata-hro.de/dataset/9c32aba3-4380-4372-b31c-d0ba53fba326',
#  'https://www.opendata-hro.de/dataset/9a61bc0e-ae39-4cb2-b986-c24a8b9d9afb',
#  'https://www.opendata-hro.de/dataset/4eea0afb-3ca1-4467-bad0-c6b4311adbf5',
#  'https://www.opendata-hro.de/dataset/41026eb8-be78-481f-af5f-7569ad623108',
#  'https://www.opendata-hro.de/dataset/efdcff26-4066-40ad-9c30-6b4d24b9024b',
#  'https://www.opendata-hro.de/dataset/0b21dcd5-802a-4250-911f-2d70cff2e3ea',
#  'https://www.opendata-hro.de/dataset/3c255c22-924a-4ea6-8231-3b9a0adc57d9',
#  'https://www.opendata-hro.de/dataset/5e7f84d6-ef16-4ca9-8f11-73c4ffdce1b8',
#  'https://www.opendata-hro.de/dataset/3cf05eb4-1e16-4010-b7e9-8dd8a3c41c60',
#  'https://www.opendata-hro.de/dataset/3d200983-34ef-4ed9-9db4-4cc7b825d316',
#  'https://www.opendata-hro.de/dataset/ea1e864d-15cb-4361-8b8e-2e597d63f461',
#  'https://www.opendata-hro.de/dataset/07ee6be5-9d7f-43ee-b9cf-06a4f8b6c53f',
#  'https://www.opendata-hro.de/dataset/c13dcce9-4fbf-45d6-aeae-d6cc908cf479',
#  'https://www.opendata-hro.de/dataset/f85e99de-1cfc-4b91-8948-69ce4dc633a5',
#  'https://www.opendata-hro.de/dataset/d2b88860-5ee9-4544-a983-c96e67f379e4',
#  'https://www.opendata-hro.de/dataset/305d5bb9-28cb-496f-ad29-09838c5dcdbc',
#  'https://www.opendata-hro.de/dataset/499d7e06-8253-4103-8098-7f75dd2f7922',
#  'https://www.opendata-hro.de/dataset/b98d3ff9-252a-4078-9764-e6467c69ecd0',
#  'https://www.opendata-hro.de/dataset/0ea6dbae-b369-49e5-9319-86e377e74a5c',
#  'https://www.opendata-hro.de/dataset/c8c24217-3166-4bbc-82e7-d17a8dd0818a',
#  'https://www.opendata-hro.de/dataset/1bc67d41-8996-4018-b9e0-eafc16971415',
#  'https://www.opendata-hro.de/dataset/b6e0fe95-710a-4657-b74e-6f148d0692a0',
#  'https://www.opendata-hro.de/dataset/6e48cf86-e713-4c31-969c-6045609f24be',
#  'https://www.opendata-hro.de/dataset/844d17ed-feea-4d50-a9c9-28a1d6b7bd42',
#  'https://www.opendata-hro.de/dataset/8636fbf4-5108-40b8-ba7d-a88adbcbe786',
#  'https://www.opendata-hro.de/dataset/a0d97824-49b9-4491-b93c-3f9e4828092a',
#  'https://www.opendata-hro.de/dataset/27e1cb37-ee30-4108-a0c6-9c98defe7c19',
#  'https://www.opendata-hro.de/dataset/db6d965d-cfe4-425c-a228-de24a328be6d',
#  'https://www.opendata-hro.de/dataset/828a46fd-4aa5-4e03-acc5-3313895f600c',
#  'https://www.opendata-hro.de/dataset/385a76bf-f4ba-40a1-a095-7831f4af677f',
#  'https://www.opendata-hro.de/dataset/d338266b-4f94-4cad-ae97-fe350baf8287',
#  'https://www.opendata-hro.de/dataset/b2e2f9be-b977-4459-a9b0-e1bf303b0d99',
#  'https://www.opendata-hro.de/dataset/f8f1193e-5cf9-45c7-b846-3db93969fcd7',
#  'https://www.opendata-hro.de/dataset/3b4cb6cb-bdb0-4d66-9bc4-d138f379d0fc',
#  'https://www.opendata-hro.de/dataset/38c996e9-bcca-46b1-82ac-e1996fd63435',
#  'https://www.opendata-hro.de/dataset/6714c938-5003-40b3-be72-e8f1c7a2f211',
#  'https://www.opendata-hro.de/dataset/1bb81cc4-c33f-492a-ba0e-f4ad0dc593c8',
#  'https://www.opendata-hro.de/dataset/0de8bbef-b14c-497b-b93d-5bac8d01908f',
#  'https://www.opendata-hro.de/dataset/c8c61d0c-c43f-40eb-b84f-18020474f4ff',
#  'https://www.opendata-hro.de/dataset/d7905714-20f5-4612-aad8-b8878bd3a852',
#  'https://www.opendata-hro.de/dataset/36d8b5ec-78ac-4c41-b948-f328bdb41e86',
#  'https://www.opendata-hro.de/dataset/3028514e-0992-48ae-88fd-d0f5c7f83adc',
#  'https://www.opendata-hro.de/dataset/178673c1-ccc3-4bba-903f-cf15b608deaa',
#  'https://www.opendata-hro.de/dataset/95dafa72-f305-4dbf-b64e-27ebab0978f0',
#  'https://www.opendata-hro.de/dataset/f62c5be6-24e1-446d-b08b-a06062b18311',
#  'https://www.opendata-hro.de/dataset/6e47f19f-ebdb-4145-95ef-05ad972d0604',
#  'https://www.opendata-hro.de/dataset/de4aa324-5072-4dd4-91f4-a49dbf063d6a',
#  'https://www.opendata-hro.de/dataset/2c61ffee-0e05-42ee-9afc-242328be728e',
#  'https://www.opendata-hro.de/dataset/b865df4b-1a29-4591-8774-45e26235a0c6',
#  'https://www.opendata-hro.de/dataset/809da8a1-2d6e-4eec-8611-ec27ad57d97d',
#  'https://www.opendata-hro.de/dataset/10ff54a4-50e6-4550-b156-4209986768fc',
#  'https://www.opendata-hro.de/dataset/e5773f72-970e-4337-a133-6a547dce7fa7',
#  'https://www.opendata-hro.de/dataset/d8f701a5-48e8-4995-86e8-42471b878986',
#  'https://www.opendata-hro.de/dataset/8f8a9f32-9247-43d9-8862-29e1c8946153',
#  'https://www.opendata-hro.de/dataset/f7e80691-34a5-4921-833d-b852efed871f',
#  'https://www.opendata-hro.de/dataset/30e72e8f-cfe0-48f4-98cd-9b8b41ed51f6',
#  'https://www.opendata-hro.de/dataset/f9ff00f8-0928-4255-8e27-d965cfeeedef',
#  'https://www.opendata-hro.de/dataset/a9486089-80ce-43ae-87fd-97f81260f34c',
#  'https://www.opendata-hro.de/dataset/cdf7d719-9049-43cf-8536-1fc6596601c0',
#  'https://www.opendata-hro.de/dataset/71160841-9f7d-45c5-aa7d-1f7b9f8a553e',
#  'https://www.opendata-hro.de/dataset/e065d236-8360-4364-9d4e-91567e3706cd',
#  'https://www.opendata-hro.de/dataset/4daded51-8ab0-454c-a805-5fe5750ebe65',
#  'https://www.opendata-hro.de/dataset/f40a0952-1f55-4ac6-bc75-45c15c9d2365',
#  'https://www.opendata-hro.de/dataset/06fe2d3f-53c7-4a7b-b362-a9235ce8a484',
#  'https://www.opendata-hro.de/dataset/42d758f4-acc9-47a5-a428-1911206c3aa5',
#  'https://www.opendata-hro.de/dataset/55a3a888-558f-4866-b0ba-a5b430923d5a',
#  'https://www.opendata-hro.de/dataset/e8d34128-b923-4e37-a18d-09ef5d6d5e61',
#  'https://www.opendata-hro.de/dataset/a8f9084d-fb11-4f53-9db0-e25984d47339',
#  'https://www.opendata-hro.de/dataset/310d8444-01f6-4432-aed1-4cd6d3b93f95',
#  'https://www.opendata-hro.de/dataset/c1be4007-d811-48fb-8818-2cb358b06a63',
#  'https://www.opendata-hro.de/dataset/934ec65d-398b-49d0-9833-9aa713c0ff87',
#  'https://www.opendata-hro.de/dataset/e2e91116-4cfe-4df4-9d06-9b6ea47da7e1',
#  'https://www.opendata-hro.de/dataset/ec4de52b-afd2-483e-9f51-f5ef96440065',
#  'https://www.opendata-hro.de/dataset/83eff2b5-4cd5-478a-96d3-46696dd3ddc2',
#  'https://www.opendata-hro.de/dataset/9dedf0da-975b-46a9-947f-8a90bc55b748',
#  'https://www.opendata-hro.de/dataset/8c953125-eec4-48c6-a562-416d36e7920f',
#  'https://www.opendata-hro.de/dataset/141c4422-a265-427f-b8b3-208e216f4008',
#  'https://www.opendata-hro.de/dataset/41e083a5-862a-4c9e-abe8-3427ac61b83b',
#  'https://www.opendata-hro.de/dataset/cd968c15-de64-4e1c-9a6f-9c1c2610b5e6',
#  'https://www.opendata-hro.de/dataset/fffea4a8-e55a-4b91-a53b-a9d598a7acfa',
#  'https://www.opendata-hro.de/dataset/31690e95-4366-4aae-bcc7-5a21828c2988',
#  'https://www.opendata-hro.de/dataset/8da7047b-cd29-463d-b2b5-bb39efdcc524',
#  'https://www.opendata-hro.de/dataset/4bdb38a2-ec28-415b-a486-31c6647773bc',
#  'https://www.opendata-hro.de/dataset/0bb5be67-dea5-4979-8ed6-afcfe26d1f63',
#  'https://www.opendata-hro.de/dataset/da57845f-ae51-41ca-944a-8f7beb132e8f',
#  'https://www.opendata-hro.de/dataset/69562564-657b-4761-8a76-a27ac1d5c70a',
#  'https://www.opendata-hro.de/dataset/871765a2-00af-4ba5-9cd8-12e0554139ed',
#  'https://www.opendata-hro.de/dataset/d5d522ae-4c02-4374-adc1-6ab6c5435825',
#  'https://www.opendata-hro.de/dataset/ba932851-6d18-482f-b9fc-98cd156ac7bc',
#  'https://www.opendata-hro.de/dataset/b876a6fe-8dda-4404-a10b-f5f6313fdf39',
#  'https://www.opendata-hro.de/dataset/035c3b2e-3704-4afc-ad2d-6eeb80ec411e',
#  'https://www.opendata-hro.de/dataset/c31cd387-aa96-42ed-ae43-4dbc8efe01ac',
#  'https://www.opendata-hro.de/dataset/93b41a30-833b-4f65-aecd-89f02ddaea4e',
#  'https://www.opendata-hro.de/dataset/5f3d484a-4831-4e2a-916f-713c6f35dc94',
#  'https://www.opendata-hro.de/dataset/3c4d2782-2558-4665-aeed-431968f74c26',
#  'https://www.opendata-hro.de/dataset/2e9e973f-3180-4197-a46e-dbd4917264a9',
#  'https://www.opendata-hro.de/dataset/50035273-5459-4cc3-b7f1-c9679a6d941c',
#  'https://www.opendata-hro.de/dataset/529971d4-e392-4d4d-9f4b-143f4a93bf03',
#  'https://www.opendata-hro.de/dataset/91bf3ccf-3407-4766-a4d3-abd3684cd747',
#  'https://www.opendata-hro.de/dataset/4b3353d0-965a-4c9a-b191-9bd6a9599730',
#  'https://www.opendata-hro.de/dataset/e0d61fb9-8369-4fba-9e9c-09eeb9f682aa',
#  'https://www.opendata-hro.de/dataset/404cee33-a87a-4ca7-a250-6355360d2b61',
#  'https://www.opendata-hro.de/dataset/0fc55ddf-b0da-4baa-931c-2e84e8dedc14',
#  'https://www.opendata-hro.de/dataset/223b597e-b3cd-4930-b38c-70ffa8961bf8',
#  'https://www.opendata-hro.de/dataset/9a765218-16b8-48ac-8b00-84969caf97ff',
#  'https://www.opendata-hro.de/dataset/68fefa03-2c9b-4275-b3e1-fabab58e1495',
#  'https://www.opendata-hro.de/dataset/e14fe109-ac46-4121-a078-50fd47fc981f',
#  'https://www.opendata-hro.de/dataset/d5d60f4a-eb66-433a-8594-35f5692ab62d',
#  'https://www.opendata-hro.de/dataset/ee6ad9fd-6853-4184-acbf-7e91052a725f',
#  'https://www.opendata-hro.de/dataset/fe33fb5a-6739-440b-843b-c17e61cad596',
#  'https://www.opendata-hro.de/dataset/e4344ed2-ca33-4fb7-ab01-3b62fce36a85',
#  'https://www.opendata-hro.de/dataset/f9fc7e81-2315-4fc9-9252-2efdcc125c13',
#  'https://www.opendata-hro.de/dataset/6cd99421-30d4-466a-930b-7a260e1240a2',
#  'https://www.opendata-hro.de/dataset/c8d7bc49-0125-4bd9-96ae-5bdef7ab9c49',
#  'https://www.opendata-hro.de/dataset/e7dba159-67b0-4956-a2fe-a0af435eecb9',
#  'https://www.opendata-hro.de/dataset/68445250-5f3b-40e3-b40e-663e41f20fee',
#  'https://www.opendata-hro.de/dataset/e06264ee-8509-4a89-8e9f-07691042bd29',
#  'https://www.opendata-hro.de/dataset/675178a8-bb06-45d8-9d77-d4140aa37d29',
#  'https://www.opendata-hro.de/dataset/38db800d-a64d-4053-8c50-f96a7f51510e',
#  'https://www.opendata-hro.de/dataset/9f7b6293-9e16-4f26-ac2a-920b20d4d830',
#  'https://www.opendata-hro.de/dataset/fb03c3c5-cae0-41cd-9256-5472b0677377',
#  'https://www.opendata-hro.de/dataset/32cc18e5-80ea-45a0-8c28-c30d04b50f02',
#  'https://www.opendata-hro.de/dataset/5ca49844-a899-4690-b163-bd0de889ffd6',
#  'https://www.opendata-hro.de/dataset/78d0d41d-e998-40b6-aa9b-adb09b512f09',
#  'https://www.opendata-hro.de/dataset/78c98423-8d83-48db-ba8c-705ff1829d6e',
#  'https://www.opendata-hro.de/dataset/0fecf0f7-2a6c-4a48-a91b-3747483709f9',
#  'https://www.opendata-hro.de/dataset/ddf5e0a2-12b8-4161-9f6f-45593bf331fc',
#  'https://www.opendata-hro.de/dataset/95a9259a-ef62-4223-9be3-36eb80cf276a',
#  'https://www.opendata-hro.de/dataset/e20b32ea-1e32-45c4-8305-2c2b8110a5bc',
#  'https://www.opendata-hro.de/dataset/01b65115-2b4b-448e-8a41-6501fa867fae',
#  'https://www.opendata-hro.de/dataset/65ed5731-5b2a-4482-bf81-95a66d3c2a7e',
#  'https://www.opendata-hro.de/dataset/ccaafa29-7055-4d14-933a-2f8feed30a3d',
#  'https://www.opendata-hro.de/dataset/b4e131a9-74f0-427a-bbe7-955d4bb17f58',
#  'https://www.opendata-hro.de/dataset/45d84fe3-5396-40e9-ae9d-938b1ddfe340',
#  'https://www.opendata-hro.de/dataset/4f787dcc-5786-455e-9f69-d147a113a7b5',
#  'https://www.opendata-hro.de/dataset/36e3596b-71d4-4bcb-bf03-040e662b5136',
#  'https://www.opendata-hro.de/dataset/fa20f85f-7781-4a77-9f3b-fe4be3184014',
#  'https://www.opendata-hro.de/dataset/875b8298-1a28-42b0-9ce4-b31e316f1196',
#  'https://www.opendata-hro.de/dataset/9e6df860-7eb4-4c5c-906a-632b6dfcec9d',
#  'https://www.opendata-hro.de/dataset/021ce124-2ac0-4aee-a3d8-a1d33932b2ac',
#  'https://www.opendata-hro.de/dataset/227b95a4-f1f0-4188-b724-acb3eba36069',
#  'https://www.opendata-hro.de/dataset/7e04955f-e864-4b4a-babf-fa59a04e4eec',
#  'https://www.opendata-hro.de/dataset/3d57acf5-d768-497a-81ff-14a77ce59d85',
#  'https://www.opendata-hro.de/dataset/466e6861-82ba-4912-b9cc-97676bef371e',
#  'https://www.opendata-hro.de/dataset/9b7cbfc5-ffcb-4b51-9227-5bfe46eacc5d',
#  'https://www.opendata-hro.de/dataset/681418b6-a6a0-44ac-9d6e-38a0a18585b4',
#  'https://www.opendata-hro.de/dataset/aed7ba93-ebd1-4e7d-9c02-30032bc523a5',
#  'https://www.opendata-hro.de/dataset/658f0d83-31e1-4f34-bdff-4498972a9163',
#  'https://www.opendata-hro.de/dataset/2b388393-97b7-482e-b7f8-c57953b5fcf0',
#  'https://www.opendata-hro.de/dataset/fb8903bb-df12-45a7-a7de-5d0f17e2fca2',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  None,
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.statistik-nord.de',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  None,
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  'http://www.hamburg.de/bgv/radioaktivitaet',
#  ...]

# %%
df.to_csv(r'C:\Users\MolnarM\Downloads\datasets_metadata_germany.csv', index=False)

# %%
import requests
import json
import time
import pandas as pd

# Define the base URL for the CKAN API
base_url = "https://data.gov.ie/api/3/action/"

# Function to get a specified number of datasets with pagination
def get_recent_datasets_metadata(limit=15000, chunk_size=100, timeout=2):
    datasets = []
    rows = 100  # Number of datasets per request (max 1000 according to CKAN API)
    start = 0
    
    while start < limit:
        search_url = base_url + "package_search"
        params = {
            "rows": min(rows, limit - start),
            "start": start
        }
        response = requests.get(search_url, params=params)
        data = response.json()
        
        if not data['success']:
            break
        
        results = data['result']['results']
        if not results:
            break
        
        datasets.extend(results)
        start += rows
        
        # Print progress in chunks to avoid overwhelming the output buffer
        if len(datasets) % chunk_size == 0:
            print(f"Retrieved {len(datasets)} datasets so far...")
        
        # Introduce a delay to avoid hitting the server too hard
        time.sleep(timeout)
    
    return datasets

# Example usage
if __name__ == "__main__":
    recent_datasets_metadata = get_recent_datasets_metadata(limit=15000)
    
    # Convert to DataFrame
    df = pd.DataFrame(recent_datasets_metadata)
    
    # Save the DataFrame to a CSV file
    df.to_csv(r'C:\Users\MolnarM\Downloads\datasets_metadata_ireland.csv', index=False)
    
    print(f"Retrieved metadata for {len(recent_datasets_metadata)} datasets. Data saved to 'datasets_metadata_ireland.csv'.")
# Out:
# Retrieved 100 datasets so far...
# Retrieved 200 datasets so far...
# Retrieved 300 datasets so far...
# Retrieved 400 datasets so far...
# Retrieved 500 datasets so far...
# Retrieved 600 datasets so far...
# Retrieved 700 datasets so far...
# Retrieved 800 datasets so far...
# Retrieved 900 datasets so far...
# Retrieved 1000 datasets so far...
# Retrieved 1100 datasets so far...
# Retrieved 1200 datasets so far...
# Retrieved 1300 datasets so far...
# Retrieved 1400 datasets so far...
# Retrieved 1500 datasets so far...
# Retrieved 1600 datasets so far...
# Retrieved 1700 datasets so far...
# Retrieved 1800 datasets so far...
# Retrieved 1900 datasets so far...
# Retrieved 2000 datasets so far...
# Retrieved 2100 datasets so far...
# Retrieved 2200 datasets so far...
# Retrieved 2300 datasets so far...
# Retrieved 2400 datasets so far...
# Retrieved 2500 datasets so far...
# Retrieved 2600 datasets so far...
# Retrieved 2700 datasets so far...
# Retrieved 2800 datasets so far...
# Retrieved 2900 datasets so far...
# Retrieved 3000 datasets so far...
# Retrieved 3100 datasets so far...
# Retrieved 3200 datasets so far...
# Retrieved 3300 datasets so far...
# Retrieved 3400 datasets so far...
# Retrieved 3500 datasets so far...
# Retrieved 3600 datasets so far...
# Retrieved 3700 datasets so far...
# Retrieved 3800 datasets so far...
# Retrieved 3900 datasets so far...
# Retrieved 4000 datasets so far...
# Retrieved 4100 datasets so far...
# Retrieved 4200 datasets so far...
# Retrieved 4300 datasets so far...
# Retrieved 4400 datasets so far...
# Retrieved 4500 datasets so far...
# Retrieved 4600 datasets so far...
# Retrieved 4700 datasets so far...
# Retrieved 4800 datasets so far...
# Retrieved 4900 datasets so far...
# Retrieved 5000 datasets so far...
# Retrieved 5100 datasets so far...
# Retrieved 5200 datasets so far...
# Retrieved 5300 datasets so far...
# Retrieved 5400 datasets so far...
# Retrieved 5500 datasets so far...
# Retrieved 5600 datasets so far...
# Retrieved 5700 datasets so far...
# Retrieved 5800 datasets so far...
# Retrieved 5900 datasets so far...
# Retrieved 6000 datasets so far...
# Retrieved 6100 datasets so far...
# Retrieved 6200 datasets so far...
# Retrieved 6300 datasets so far...
# Retrieved 6400 datasets so far...
# Retrieved 6500 datasets so far...
# Retrieved 6600 datasets so far...
# Retrieved 6700 datasets so far...
# Retrieved 6800 datasets so far...
# Retrieved 6900 datasets so far...
# Retrieved 7000 datasets so far...
# Retrieved 7100 datasets so far...
# Retrieved 7200 datasets so far...
# Retrieved 7300 datasets so far...
# Retrieved 7400 datasets so far...
# Retrieved 7500 datasets so far...
# Retrieved 7600 datasets so far...
# Retrieved 7700 datasets so far...
# Retrieved 7800 datasets so far...
# Retrieved 7900 datasets so far...
# Retrieved 8000 datasets so far...
# Retrieved 8100 datasets so far...
# Retrieved 8200 datasets so far...
# Retrieved 8300 datasets so far...
# Retrieved 8400 datasets so far...
# Retrieved 8500 datasets so far...
# Retrieved 8600 datasets so far...
# Retrieved 8700 datasets so far...
# Retrieved 8800 datasets so far...
# Retrieved 8900 datasets so far...
# Retrieved 9000 datasets so far...
# Retrieved 9100 datasets so far...
# Retrieved 9200 datasets so far...
# Retrieved 9300 datasets so far...
# Retrieved 9400 datasets so far...
# Retrieved 9500 datasets so far...
# Retrieved 9600 datasets so far...
# Retrieved 9700 datasets so far...
# Retrieved 9800 datasets so far...
# Retrieved 9900 datasets so far...
# Retrieved 10000 datasets so far...
# Retrieved 10100 datasets so far...
# Retrieved 10200 datasets so far...
# Retrieved 10300 datasets so far...
# Retrieved 10400 datasets so far...
# Retrieved 10500 datasets so far...
# Retrieved 10600 datasets so far...
# Retrieved 10700 datasets so far...
# Retrieved 10800 datasets so far...
# Retrieved 10900 datasets so far...
# Retrieved 11000 datasets so far...
# Retrieved 11100 datasets so far...
# Retrieved 11200 datasets so far...
# Retrieved 11300 datasets so far...
# Retrieved 11400 datasets so far...
# Retrieved 11500 datasets so far...
# Retrieved 11600 datasets so far...
# Retrieved 11700 datasets so far...
# Retrieved 11800 datasets so far...
# Retrieved 11900 datasets so far...
# Retrieved 12000 datasets so far...
# Retrieved 12100 datasets so far...
# Retrieved 12200 datasets so far...
# Retrieved 12300 datasets so far...
# Retrieved 12400 datasets so far...
# Retrieved 12500 datasets so far...
# Retrieved 12600 datasets so far...
# Retrieved 12700 datasets so far...
# Retrieved 12800 datasets so far...
# Retrieved 12900 datasets so far...
# Retrieved 13000 datasets so far...
# Retrieved 13100 datasets so far...
# Retrieved 13200 datasets so far...
# Retrieved 13300 datasets so far...
# Retrieved 13400 datasets so far...
# Retrieved 13500 datasets so far...
# Retrieved 13600 datasets so far...
# Retrieved 13700 datasets so far...
# Retrieved 13800 datasets so far...
# Retrieved 13900 datasets so far...
# Retrieved 14000 datasets so far...
# Retrieved 14100 datasets so far...
# Retrieved 14200 datasets so far...
# Retrieved 14300 datasets so far...
# Retrieved 14400 datasets so far...
# Retrieved 14500 datasets so far...
# Retrieved 14600 datasets so far...
# Retrieved 14700 datasets so far...
# Retrieved 14800 datasets so far...
# Retrieved 14900 datasets so far...
# Retrieved 15000 datasets so far...
# Retrieved metadata for 15000 datasets. Data saved to 'datasets_metadata_ireland.csv'.

# %%
import requests
import json
import time
import pandas as pd

# Define the base URL for the CKAN API
base_url = "https://opendata.swiss/api/3/action/"

# Function to get a specified number of datasets with pagination
def get_recent_datasets_metadata(limit=15000, chunk_size=100, timeout=2):
    datasets = []
    rows = 100  # Number of datasets per request (max 1000 according to CKAN API)
    start = 0
    
    while start < limit:
        search_url = base_url + "package_search"
        params = {
            "rows": min(rows, limit - start),
            "start": start
        }
        response = requests.get(search_url, params=params)
        data = response.json()
        
        if not data['success']:
            break
        
        results = data['result']['results']
        if not results:
            break
        
        datasets.extend(results)
        start += rows
        
        # Print progress in chunks to avoid overwhelming the output buffer
        if len(datasets) % chunk_size == 0:
            print(f"Retrieved {len(datasets)} datasets so far...")
        
        # Introduce a delay to avoid hitting the server too hard
        time.sleep(timeout)
    
    return datasets

# Example usage
if __name__ == "__main__":
    recent_datasets_metadata = get_recent_datasets_metadata(limit=15000)
    
    # Convert to DataFrame
    df = pd.DataFrame(recent_datasets_metadata)
    
    # Save the DataFrame to a CSV file
    df.to_csv('datasets_metadata_switzerland.csv', index=False)
    
    print(f"Retrieved metadata for {len(recent_datasets_metadata)} datasets. Data saved to 'datasets_metadata_switzerland.csv'.")
# Out:
# Retrieved 100 datasets so far...
# Retrieved 200 datasets so far...
# Retrieved 300 datasets so far...
# Retrieved 400 datasets so far...
# Retrieved 500 datasets so far...
# Retrieved 600 datasets so far...
# Retrieved 700 datasets so far...
# Retrieved 800 datasets so far...
# Retrieved 900 datasets so far...
# Retrieved 1000 datasets so far...
# Retrieved 1100 datasets so far...
# Retrieved 1200 datasets so far...
# Retrieved 1300 datasets so far...
# Retrieved 1400 datasets so far...
# Retrieved 1500 datasets so far...
# Retrieved 1600 datasets so far...
# Retrieved 1700 datasets so far...
# Retrieved 1800 datasets so far...
# Retrieved 1900 datasets so far...
# Retrieved 2000 datasets so far...
# Retrieved 2100 datasets so far...
# Retrieved 2200 datasets so far...
# Retrieved 2300 datasets so far...
# Retrieved 2400 datasets so far...
# Retrieved 2500 datasets so far...
# Retrieved 2600 datasets so far...
# Retrieved 2700 datasets so far...
# Retrieved 2800 datasets so far...
# Retrieved 2900 datasets so far...
# Retrieved 3000 datasets so far...
# Retrieved 3100 datasets so far...
# Retrieved 3200 datasets so far...
# Retrieved 3300 datasets so far...
# Retrieved 3400 datasets so far...
# Retrieved 3500 datasets so far...
# Retrieved 3600 datasets so far...
# Retrieved 3700 datasets so far...
# Retrieved 3800 datasets so far...
# Retrieved 3900 datasets so far...
# Retrieved 4000 datasets so far...
# Retrieved 4100 datasets so far...
# Retrieved 4200 datasets so far...
# Retrieved 4300 datasets so far...
# Retrieved 4400 datasets so far...
# Retrieved 4500 datasets so far...
# Retrieved 4600 datasets so far...
# Retrieved 4700 datasets so far...
# Retrieved 4800 datasets so far...
# Retrieved 4900 datasets so far...
# Retrieved 5000 datasets so far...
# Retrieved 5100 datasets so far...
# Retrieved 5200 datasets so far...
# Retrieved 5300 datasets so far...
# Retrieved 5400 datasets so far...
# Retrieved 5500 datasets so far...
# Retrieved 5600 datasets so far...
# Retrieved 5700 datasets so far...
# Retrieved 5800 datasets so far...
# Retrieved 5900 datasets so far...
# Retrieved 6000 datasets so far...
# Retrieved 6100 datasets so far...
# Retrieved 6200 datasets so far...
# Retrieved 6300 datasets so far...
# Retrieved 6400 datasets so far...
# Retrieved 6500 datasets so far...
# Retrieved 6600 datasets so far...
# Retrieved 6700 datasets so far...
# Retrieved 6800 datasets so far...
# Retrieved 6900 datasets so far...
# Retrieved 7000 datasets so far...
# Retrieved 7100 datasets so far...
# Retrieved 7200 datasets so far...
# Retrieved 7300 datasets so far...
# Retrieved 7400 datasets so far...
# Retrieved 7500 datasets so far...
# Retrieved 7600 datasets so far...
# Retrieved 7700 datasets so far...
# Retrieved 7800 datasets so far...
# Retrieved 7900 datasets so far...
# Retrieved 8000 datasets so far...
# Retrieved 8100 datasets so far...
# Retrieved 8200 datasets so far...
# Retrieved 8300 datasets so far...
# Retrieved 8400 datasets so far...
# Retrieved 8500 datasets so far...
# Retrieved 8600 datasets so far...
# Retrieved 8700 datasets so far...
# Retrieved 8800 datasets so far...
# Retrieved 8900 datasets so far...
# Retrieved 9000 datasets so far...
# Retrieved 9100 datasets so far...
# Retrieved 9200 datasets so far...
# Retrieved 9300 datasets so far...
# Retrieved 9400 datasets so far...
# Retrieved 9500 datasets so far...
# Retrieved 9600 datasets so far...
# Retrieved 9700 datasets so far...
# Retrieved 9800 datasets so far...
# Retrieved 9900 datasets so far...
# Retrieved 10000 datasets so far...
# Retrieved 10100 datasets so far...
# Retrieved 10200 datasets so far...
# Retrieved 10300 datasets so far...
# Retrieved 10400 datasets so far...
# Retrieved 10500 datasets so far...
# Retrieved 10600 datasets so far...
# Retrieved 10700 datasets so far...
# Retrieved 10800 datasets so far...
# Retrieved 10900 datasets so far...
# Retrieved 11000 datasets so far...
# Retrieved 11100 datasets so far...
# Retrieved 11200 datasets so far...
# Retrieved 11300 datasets so far...
# Retrieved 11400 datasets so far...
# Retrieved 11500 datasets so far...
# Retrieved 11600 datasets so far...
# Retrieved 11700 datasets so far...
# Retrieved 11800 datasets so far...
# Retrieved metadata for 11892 datasets. Data saved to 'datasets_metadata_switzerland.csv'.

# %%
df.to_csv(r'C:\Users\MolnarM\Downloads\datasets_metadata_switzerland.csv')
